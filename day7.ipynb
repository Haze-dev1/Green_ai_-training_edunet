# %%
import seaborn as sns
tip_df = sns.load_dataset("tips")
tip_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill", y="tip", hue="day", style="time", size="size", data=tip_df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x="total_bill", y="tip", data=tip_df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#load Resources/appliance_energy.csv dataset
import pandas as pd
energy_df = pd.read_csv("Resources/appliance_energy.csv")
energy_df.head()
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
#rename the column
energy_df.rename(columns={'Temperature(C)':'temperature','Energy Consumption(kWh)':'energy_consumption'}, inplace=True)
energy_df.head()
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
# Debugging: Check column names after renaming
print("Column names:", energy_df.columns)
# Out:
# Column names: Index(['Temperature (°C)', 'Energy Consumption (kWh)'], dtype='str')

# %%
sns.scatterplot(x='temperature', y='energy_consumption', data=energy_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.scatterplot(x='temperature', y='energy_consumption', data=energy_df)
#
# File ~/.local/lib/python3.14/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
x= energy_df['temperature']
y = energy_df['energy_consumption
# Out:
#   Cell In[2], line 2
#     y = energy_df['energy_consumption
#                   ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
x[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x[:5]
#
# NameError: name 'x' is not defined

# %%
#split the data into training and testing data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #split the data into training and testing data
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
#
# NameError: name 'x' is not defined
