# %%
XYZ = "I love linux and i suggest everyone to use it"
print(XYZ)
print(XYZ[len(XYZ) // 2])
# Out:
# I love linux and i suggest everyone to use it
# g

# %%
for i in XYZ:
    print(i)
# Out:
# I
#
# l
# o
# v
# e
#
# l
# i
# n
# u
# x
#
# a
# n
# d
#
# i
#
# s
# u
# g
# g
# e
# s
# t
#
# e
# v
# e
# r
# y
# o
# n
# e
#
# t
# o
#
# u
# s
# e
#
# i
# t

# %%
XYZ[::-1]
# Out:
# 'ti esu ot enoyreve tseggus i dna xunil evol I'
